# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from RNN import RNN
from data_generator import BanditDataset
from evaluation import repeat_probability_eval, quantitative_eval, evaluate, uncertainty_generalization_eval

# %%
train_data = BanditDataset.load('train')
train_data.plot(1)

# %%
val_data = BanditDataset.load('val')
val_data.plot(1)

# %% [markdown]
# # Evaluation

# %%
model = RNN.load('version_9')
# Out:
# Loading RNN (version_9) - checkpoint from lightning_logs/version_9/checkpoints/epoch=198-step=19900.ckpt

# %%
quantitative_eval(model)
# Out:
# Loaded test set located in data
# Avg. Accuracy on test set:  0.7155500054359436
# Avg. Excess reward on test set:  0.17765234410762787

# %%
uncertainty_generalization_eval(model, seed=10, batch_size=100)
# Out:
# Generating evaluation sets of size 100: 100%|██████████| 64/64 [23:35<00:00,  1.37s/it]
# Generating evaluation sets of size 100: 100%|██████████| 64/64 [23:35<00:00, 22.12s/it]

# %%
repeat_probability_eval(model)
# Out:
# Loaded test set located in data

# %% [markdown]
# # With inequity loss * 0.1

# %%
model = RNN.load('version_13')
# Out:
# Loading RNN (version_13) - checkpoint from lightning_logs/version_13/checkpoints/epoch=199-step=20000.ckpt

# %%
evaluate(model, seed=42)
# Out:
# Loaded test set located in data
# Avg. Accuracy on test set:  0.7153375148773193
# Avg. Excess reward on test set:  0.17825725674629211
# Generating evaluation sets of size 100: 100%|██████████| 64/64 [23:58<00:00,  1.35s/it]
# Generating evaluation sets of size 100: 100%|██████████| 64/64 [23:58<00:00, 22.47s/it]
# Loaded test set located in data

# %% [markdown]
# ## With inequity loss * 1

# %%
model = RNN.load('version_14')
evaluate(model, seed=1)
# Out:
# Loading RNN (version_14) - checkpoint from lightning_logs/version_14/checkpoints/epoch=199-step=20000.ckpt
# Loaded test set located in data
# Avg. Accuracy on test set:  0.7172750234603882
# Avg. Excess reward on test set:  0.1789284646511078
# Generating evaluation sets of size 100: 100%|██████████| 64/64 [23:22<00:00,  1.32s/it]
# Generating evaluation sets of size 100: 100%|██████████| 64/64 [23:22<00:00, 21.91s/it]
# Loaded test set located in data

# %% [markdown]
# ## Inequity * 2

# %%
model = RNN.load('version_16')
evaluate(model, seed=1, quick=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 model = RNN.load('version_16')
#       2 evaluate(model, seed=1, quick=True)
#
# File ~/PycharmProjects/social_bandit/RNN.py:170, in RNN.load(cls, version)
#     163 @classmethod
#     164 def load(cls, version: str):
#     165     checkpoint_path = glob.glob(os.path.join(
#     166         MODEL_DIR,
#     167         version,
#     168         'checkpoints/*.ckpt'
#     169     ))[-1]
# --> 170     model = cls.load_from_checkpoint(checkpoint_path, map_location=DEVICE)
#     171     model.version = version
#     172     print(f'Loading RNN ({version}) - checkpoint from {checkpoint_path}')
#
# File ~/anaconda3/envs/social_bandit/lib/python3.10/site-packages/lightning/pytorch/core/module.py:1543, in LightningModule.load_from_checkpoint(cls, checkpoint_path, map_location, hparams_file, strict, **kwargs)
#    1463 @classmethod
#    1464 def load_from_checkpoint(
#    1465     cls,
#    (...)
#    1470     **kwargs: Any,
#    1471 ) -> Self:
#    1472     r"""
#    1473     Primary way of loading a model from a checkpoint. When Lightning saves a checkpoint
#    1474     it stores the arguments passed to ``__init__``  in the checkpoint under ``"hyper_parameters"``.
#    (...)
#    1541         y_hat = pretrained_model(x)
#    1542     """
# -> 1543     loaded = _load_from_checkpoint(
#    1544         cls,
#    1545         checkpoint_path,
#    1546         map_location,
#    1547         hparams_file,
#    1548         strict,
#    1549         **kwargs,
#    1550     )
#    1551     return cast(Self, loaded)
#
# File ~/anaconda3/envs/social_bandit/lib/python3.10/site-packages/lightning/pytorch/core/saving.py:91, in _load_from_checkpoint(cls, checkpoint_path, map_location, hparams_file, strict, **kwargs)
#      89     return _load_state(cls, checkpoint, **kwargs)
#      90 if issubclass(cls, pl.LightningModule):
# ---> 91     model = _load_state(cls, checkpoint, strict=strict, **kwargs)
#      92     state_dict = checkpoint["state_dict"]
#      93     if not state_dict:
#
# File ~/anaconda3/envs/social_bandit/lib/python3.10/site-packages/lightning/pytorch/core/saving.py:144, in _load_state(cls, checkpoint, strict, **cls_kwargs_new)
#     140 if not cls_spec.varkw:
#     141     # filter kwargs according to class init unless it allows any argument via kwargs
#     142     _cls_kwargs = {k: v for k, v in _cls_kwargs.items() if k in cls_init_args_name}
# --> 144 obj = cls(**_cls_kwargs)
#     146 if isinstance(obj, pl.LightningModule):
#     147     # give model a chance to load something
#     148     obj.on_load_checkpoint(checkpoint)
#
# TypeError: RNN.__init__() missing 2 required positional arguments: 'reward_loss_coef' and 'equity_loss_coef'

# %% [markdown]
# # Inequity * 1000

# %%
model = RNN.load('version_17')
evaluate(model, seed=1, quick=True)
# Out:
# Loading RNN (version_17) - checkpoint from lightning_logs/version_17/checkpoints/epoch=199-step=20000.ckpt
# Loaded test set located in data
# Avg. Accuracy on test set:  0.715624988079071
# Avg. Excess reward on test set:  0.1791152060031891
# Loaded test set located in data

# %% [markdown]
# # Multiple Coefficients

# %%
model = RNN.load('version_19')
evaluate(model, seed=1)
# Out:
# Loading RNN (version_19) - checkpoint from lightning_logs/version_19/checkpoints/epoch=136-step=13700.ckpt
# Avg. Accuracy on test set: 0.715
# Avg. Excess reward on test set: 0.178
# Avg. Inequity on test set: -5.892

# %%
model = RNN.load('version_20')
evaluate(model, seed=1)
# Out:
# Loading RNN (version_20) - checkpoint from lightning_logs/version_20/checkpoints/epoch=199-step=20000.ckpt
# Avg. Accuracy on test set: 0.498
# Avg. Excess reward on test set: -0.000
# Avg. Inequity on test set: 2.047
