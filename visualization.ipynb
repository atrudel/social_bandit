# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from data import BanditDataset
import numpy as np

# %%
data = BanditDataset('train.npy')

# %%
data.plot(3)
