# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from data_generator import BanditDataset
import numpy as np

# %%
train_data = BanditDataset('train')
train_data.plot(1)
# Out:
# Loaded train set located in .

# %%
val_data = BanditDataset('val')
val_data.plot(1)
# Out:
# Loaded val set located in .

# %% [markdown]
# # Evaluation

# %%
from RNN import RNN
from evaluation import evaluate

model_path = 'lightning_logs/version_8/checkpoints/epoch=199-step=20000.ckpt'
model = RNN.load_from_checkpoint(model_path)
evaluate(model, seed=10)
# Out:
# Loaded test set located in .
# Avg. Accuracy on test set:  0.7496125102043152
# Avg. Excess reward on test set:  0.24553561210632324
# (1000, 1)
#   0%|          | 0/20 [00:00<?, ?it/s]
#
#
#
# Generating trajectories:   0%|          | 0/20 [00:00<?, ?it/s]
#
#
#
# Generating trajectories:   5%|▌         | 1/20 [00:01<00:33,  1.78s/it]
#
#
#
# Generating trajectories:  10%|█         | 2/20 [00:14<02:25,  8.08s/it]
#
#
#
# Generating trajectories:  15%|█▌        | 3/20 [00:23<02:25,  8.57s/it]
#
#
#
# Generating trajectories:  20%|██        | 4/20 [01:04<05:39, 21.24s/it]
#
#
#
# Generating trajectories:  25%|██▌       | 5/20 [01:15<04:24, 17.66s/it]
#
#
#
# Generating trajectories:  30%|███       | 6/20 [01:22<03:15, 13.93s/it]
#
#
#
#   0%|          | 0/20 [02:23<?, ?it/s]  | 7/20 [01:40<03:20, 15.41s/it]
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
# ...
